# %%
run run0.py
# Out:
# C:\Users\svetl\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ******************************************************
# Random
# ******************************************************
# Experiment: 0
# ['NDNY']
# Epoch: 1, LOSS train 33.00615659356117 valid 73.25827026367188
# Epoch: 2, LOSS train 67.63143157958984 valid 26.82603645324707
# Epoch: 3, LOSS train 17.75575065612793 valid 529.0780029296875
# Epoch: 4, LOSS train 346.39415740966797 valid 11.502177238464355
# Epoch: 5, LOSS train 16.63838291168213 valid 27.79145622253418
# Epoch: 6, LOSS train 31.44261932373047 valid 31.99524688720703
# Epoch: 7, LOSS train 34.63307857513428 valid 29.494049072265625
# Model, ROC AUC: 0.500
#
# ['NDNY', 'VDRE']
# Epoch: 1, LOSS train 31.570854504903156 valid 0.6095564365386963
# ...

# %%
run run1.py
# Out:
# ******************************************************
# Hamming approach
# ******************************************************
# Experiment: 0
# ['NDNY']
# Epoch: 1, LOSS train 33.00615659356117 valid 73.25827026367188
# Epoch: 2, LOSS train 67.63143157958984 valid 26.82603645324707
# Epoch: 3, LOSS train 17.75575065612793 valid 529.0780029296875
# Epoch: 4, LOSS train 346.39415740966797 valid 11.502177238464355
# Epoch: 5, LOSS train 16.63838291168213 valid 27.79145622253418
# Epoch: 6, LOSS train 31.44261932373047 valid 31.99524688720703
# Epoch: 7, LOSS train 34.63307857513428 valid 29.494049072265625
# Model, ROC AUC: 0.500
#
# ['NDNY', 'VDQD']
# Epoch: 1, LOSS train 11.575610478719076 valid 0.33043766021728516
# Epoch: 2, LOSS train 14.634858610418936 valid 2.164247751235962
# Epoch: 3, LOSS train 1.8903992970784504 valid 7.811924457550049
# Epoch: 4, LOSS train 2.924940824508667 valid 5.5297136306762695
# Model, ROC AUC: 0.785
#
# ...

# %%
run run2.py
# Out:
# ******************************************************
# Gradient with confounding labels approach
# ******************************************************
# Experiment: 0
# ['NDNY']
# Epoch: 1, LOSS train 33.00615659356117 valid 73.25827026367188
# Epoch: 2, LOSS train 67.63143157958984 valid 26.82603645324707
# Epoch: 3, LOSS train 17.75575065612793 valid 529.0780029296875
# Epoch: 4, LOSS train 346.39415740966797 valid 11.502177238464355
# Epoch: 5, LOSS train 16.63838291168213 valid 27.79145622253418
# Epoch: 6, LOSS train 31.44261932373047 valid 31.99524688720703
# Epoch: 7, LOSS train 34.63307857513428 valid 29.494049072265625
# Model, ROC AUC: 0.500
#
# ['NDNY', 'PPNY']
# Epoch: 1, LOSS train 28.773502031962078 valid 0.2823224365711212
# Epoch: 2, LOSS train 25.339161495367687 valid 0.3343580663204193
# Epoch: 3, LOSS train 0.7737479011217753 valid 1.7414723634719849
# Epoch: 4, LOSS train 2.0337870915730796 valid 1.378111481666565
# Model, ROC AUC: 0.837
#
# ...
